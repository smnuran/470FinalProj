# %%
import json
import pandas as pd

# %%
train_data = 'small.buzztrain.json'

with open(train_data) as f:
            train = json.load(f)

# %%
questions = train['questions']

df = pd.DataFrame(questions)

# %%
data_df = pd.read_csv('output_data_csv')

data_df.head(5)
# Out:
#      Unnamed: 0                                           question  \
# 0             0  .One film produced in this country takes place...
# 1             1  .One film produced in this country takes place...
# 2             2  .One film produced in this country takes place...
# 3             3  .One film produced in this country takes place...
# 4             4  .One film produced in this country takes place...
# ..          ...                                                ...
# 195         195  .One of the most famous cult practices associa...
# 196         196  .One of the most famous cult practices associa...
# 197         197  .One of the most famous cult practices associa...
# 198         198  .One of the most famous cult practices associa...
# 199         199  .One of the most famous cult practices associa...
#
#                                   correct_answer                guess   buzz
# 0    Kingdom of Sweden [or Konungariket Sverige]  Battleship_Potemkin  False
# 1    Kingdom of Sweden [or Konungariket Sverige]                David  False
# 2    Kingdom of Sweden [or Konungariket Sverige]  Battleship_Potemkin  False
# 3    Kingdom of Sweden [or Konungariket Sverige]        Martin_Luther  False
# 4    Kingdom of Sweden [or Konungariket Sverige]        Martin_Luther  False
# ..                                           ...                  ...    ...
# 195                                      Artemis                 Bear  False
# 196                                      Artemis                 Bear  False
# 197                                      Artemis                 Bear  False
# 198                                      Artemis                 Bear  False
# 199                                      Artemis             Tantalus  False
#
# [200 rows x 5 columns]

# %%
def sentence_count(str):
    return len(str.split("."))

def guess_word_count(str):
    return len(str.split("_"))

def guess_has_paren(str):
    return int("(" in str or ")" in str)

def guess_length(str):
    return len(str)

data_df["sentence_count"]  = data_df["question"].apply(sentence_count)
data_df["guess_word_count"]  = data_df["guess"].apply(guess_word_count)
data_df["guess_has_paren"]  = data_df["guess"].apply(guess_has_paren)
data_df["guess_length"]  = data_df["guess"].apply(guess_length)

# %%
from transformers import pipeline

ner_pipeline = pipeline("ner")

def guess_entity(text):
  entities = ner_pipeline(text)
  print("Entities:", entities)
  if len(entities) == 0:
    return ""
  return entities[0]


data_df["guess_entity"] = data_df["guess"].apply(guess_entity)

# %%
data_df.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0  .One film produced in this country takes place...
# 1           1  .One film produced in this country takes place...
# 2           2  .One film produced in this country takes place...
# 3           3  .One film produced in this country takes place...
# 4           4  .One film produced in this country takes place...
#
#                                 correct_answer                guess   buzz  \
# 0  Kingdom of Sweden [or Konungariket Sverige]  Battleship_Potemkin  False
# 1  Kingdom of Sweden [or Konungariket Sverige]                David  False
# 2  Kingdom of Sweden [or Konungariket Sverige]  Battleship_Potemkin  False
# 3  Kingdom of Sweden [or Konungariket Sverige]        Martin_Luther  False
# 4  Kingdom of Sweden [or Konungariket Sverige]        Martin_Luther  False
#
#    sentence_count  guess_word_count  guess_has_paren  guess_length  \
# 0               2                 2                0            19
# 1               3                 1                0             5
# 2               4                 2                0            19
# 3               5                 2                0            13
# 4               6                 2                0            13
#
#                                         guess_entity
# 0  {'entity': 'I-MISC', 'score': 0.90084857, 'ind...
# 1  {'entity': 'I-PER', 'score': 0.9964824, 'index...
# 2  {'entity': 'I-MISC', 'score': 0.90084857, 'ind...
# 3  {'entity': 'I-PER', 'score': 0.99532074, 'inde...
# 4  {'entity': 'I-PER', 'score': 0.99532074, 'inde...

# %%
def parse_entity(entity):
  if entity == "":
    return ""
  return entity["entity"]

data_df["guess_entity"] = data_df["guess_entity"].apply(parse_entity)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-261108f22ac6> in <cell line: 6>()
#       4   return entity["entity"]
#       5
# ----> 6 data_df["guess_entity"] = data_df["guess_entity"].apply(parse_entity)
#       7
#       8 data_df["guess_entity"].value_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1074             else:
#    1075                 values = obj.astype(object)._values
# -> 1076                 mapped = lib.map_infer(
#    1077                     values,
#    1078                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-40-261108f22ac6> in parse_entity(entity)
#       2   if entity == "":
#       3     return ""
# ----> 4   return entity["entity"]
#       5
#       6 data_df["guess_entity"] = data_df["guess_entity"].apply(parse_entity)
#
# TypeError: string indices must be integers

# %%
dummies = pd.get_dummies(data_df["guess_entity"])

# %%
data_df.sort_values(by=['buzz'], ascending=False)
# Out:
#       Unnamed: 0                                           question  \
# 6839        6839  One porous form of this element is useful for ...
# 5047        5047  .This ruler set up a system of authority and l...
# 5049        5049  .This ruler set up a system of authority and l...
# 5050        5050  .This ruler set up a system of authority and l...
# 5051        5051  .This ruler set up a system of authority and l...
# ...          ...                                                ...
# 2442        2442  .While in college she was head of a science an...
# 2441        2441  .While in college she was head of a science an...
# 2440        2440  .While in college she was head of a science an...
# 2434        2434  .This school greatly influenced Geido and the ...
# 3420        3420  .The title of this play was allegedly discover...
#
#                                          correct_answer                guess  \
# 6839                                           {carbon}               Carbon
# 5047  {Charlemagne} [or Charles I; or Charles the {G...          Charlemagne
# 5049  {Charlemagne} [or Charles I; or Charles the {G...          Charlemagne
# 5050  {Charlemagne} [or Charles I; or Charles the {G...          Charlemagne
# 5051  {Charlemagne} [or Charles I; or Charles the {G...          Charlemagne
# ...                                                 ...                  ...
# 2442                                      Margaret Mead        James_Baldwin
# 2441                                      Margaret Mead        James_Baldwin
# 2440                                      Margaret Mead                  Cat
# 2434                                       Zen Buddhism  Hudson_River_School
# 3420                  {Who's Afraid of Virginia Woolf?}         Edward_Albee
#
#        buzz  sentence_count  guess_word_count  guess_has_paren  guess_length
# 6839   True               5                 1                0             6
# 5047   True               3                 1                0            11
# 5049   True               5                 1                0            11
# 5050   True               6                 1                0            11
# 5051   True               7                 1                0            11
# ...     ...             ...               ...              ...           ...
# 2442  False               4                 2                0            13
# 2441  False               3                 2                0            13
# 2440  False               2                 1                0             3
# 2434  False               3                 3                0            19
# 3420  False               5                 2                0            12
#
# [6840 rows x 9 columns]

# %%
X = data_df[["sentence_count", "guess_word_count", "guess_has_paren", "guess_length"]]
Y = data_df["buzz"]

X = pd.concat([X, dummies], axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
train, test, train_labels, test_labels = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression(class_weight='balanced', random_state = 0)
model.fit(train, train_labels)
# Out:
# LogisticRegression(class_weight='balanced', random_state=0)

# %%
test_pred = model.predict(test)

accuracy_score(test_labels, test_pred)
# Out:
# 0.6074561403508771

# %%
coefficients = model.coef_

for coef, feature_name in zip(coefficients[0], X.columns):
    print(f"{feature_name}: {coef}")
# Out:
# sentence_count: 0.27348637152316546
# guess_word_count: 0.17981194231629538
# guess_has_paren: -1.1791533084966264
# guess_length: -0.016520933637106012
# : 0.04409446309716384
# I-LOC: -0.5859127041006555
# I-MISC: 0.31285392317579835
# I-ORG: 0.33520477393222003
# I-PER: -0.10022708449378315

# %%
import pickle

with open('logreg_buzzer_model.pkl', 'wb') as f:
    pickle.dump(model, f)



pickle.load
